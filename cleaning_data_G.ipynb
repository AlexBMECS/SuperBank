# %%
from IPython.display import Image
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
import warnings
warnings.simplefilter("ignore")
# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = [12, 12]
from sklearn import datasets as ds
from sklearn.linear_model import LinearRegression
import tensorflow as tf

# %%
data_original = pd.read_csv("data/dataG/dataG_part0.csv")
data = data_original

# %%
filestart = "data/dataG/dataG_part"
fileend = ".csv"
data["SK_ID_CURR"].count()
# Out:
# 1000

# %%
frames = []

for file in range(99):
    frames.append(pd.read_csv(filestart + str(file) +fileend))

# %%
result = pd.concat(frames)

# %%
result.head()
# Out:
#    SK_ID_CURR  FLAG_DOCUMENT_21  FLAG_PHONE  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# 0      100004                 0           1              NaN             NaN
# 1      100006                 0           0              NaN             NaN
# 2      100012                 0           0              NaN             NaN
# 3      100014                 0           0              NaN             NaN
# 4      100015                 0           1              NaN             NaN
#
#    LIVE_CITY_NOT_WORK_CITY  REG_CITY_NOT_LIVE_CITY  LIVINGAPARTMENTS_MEDI  \
# 0                        0                       0                    NaN
# 1                        0                       0                    NaN
# 2                        0                       0                    NaN
# 3                        0                       0                    NaN
# 4                        0                       0                    NaN
#
#    FLAG_DOCUMENT_10  FLAG_DOCUMENT_17 AMT_GOODS_PRICE
# ...

# %%
result = result.rename(columns={'SK_ID_CURR': 'SK_ID'})

# %%
result
# Out:
#      SK_ID_CURR  FLAG_DOCUMENT_21  FLAG_PHONE  YEARS_BUILD_AVG  \
# 0        100004                 0           1              NaN
# 1        100006                 0           0              NaN
# 2        100012                 0           0              NaN
# 3        100014                 0           0              NaN
# 4        100015                 0           1              NaN
# 5        100017                 0           0           0.7348
# 6        100018                 0           0           0.9796
# 7        100019                 0           0              NaN
# 8        100030                 0           1           0.7008
# 9        100032                 0           0              NaN
# 10       100034                 0           0           0.7688
# 11       100035                 0           0              NaN
# 12       100040                 0           0           0.6736
# 13       100043                 0           1              NaN
# ...

# %%
result = result.to_csv("data/dataG_clean_v1.csv")
